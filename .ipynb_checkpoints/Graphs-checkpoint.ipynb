# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import sqlite3

# %%
df=pd.read_csv("NewlyAddedTestsReport.csv")

# %%
X, Y = np.unique(df.Component, return_counts=True)

size = np.shape(X)[0]

# %%
print data[1]
# Out:
# [ 11   4  13   8  32   9   2   8 300  28  73   2 105  22   1]

# %%
sData = zip(*sorted(zip(data[1], data[0])))
Y, X = sData
X = np.array(X)
Y = np.array(Y)

# %%
print X
# Out:
# ['iModelBridge' 'Dwg' 'Units' 'BeSQLite' 'ComponentModeling' 'ECDb'
#  'DgnV8' 'BeHttp' 'Bentley' 'ecobjects' 'GeoCoord' 'DgnPlatform'
#  'GeomLibs' 'WSClient' 'ECPresentation']

# %%
fig = plt.figure(figsize=(size+5,size))
sns.set_style("whitegrid")

colors = sns.color_palette("cubehelix", len(df.Component.unique()) + 10)

for i in range(size):
    g = sns.barplot(y=X[i:i+1], x=Y[i:i+1], color=colors[i], order = X, url = X[i]+'.svg', orient='h')
    g.text(Y[i] + 3, i + 0.1, Y[i], color='black', ha="center", weight="bold")

g.set_title("Tests added between ___ and ___")
sns.despine(left=True)
plt.savefig("TEST/test1.svg")

# %%
df.head(20)
# Out:
#                 TestCase                                           TestName  \
# 0      FakeServerFixture                            UpdateSeedFileWithDummy
# 1      FakeServerFixture                               PulliModelChangeSets
# 2      FakeServerFixture                                       TestFileCopy
# 3    RevisionTestFixture                     OptimisiticConcurrencyConflict
# 4                 Spiral                                           DocCheck
# 5                 Spiral                              SignedDistanceLangham
# 6           RuledSurface          ChiseledPipesFromArbitrarySectionEllipses
# 7   SchemaValidatorTests                         TestSchemaReferenceVersion
# 8   SchemaValidatorTests     MixinClassMayNotOverrideInheritedMixinProperty
# 9   SchemaValidatorTests    MixinClassMayNotOverrideInheritedEntityProperty
# 10  SchemaValidatorTests       EntityClassMayOverrideInheritedMixinProperty
# 11  SchemaValidatorTests  EntityClassMayNotInheritFromMultipleEntityBase...
# 12  SchemaValidatorTests  EntityClassMayNotInheritPropertyFromMultipleMi...
# 13  SchemaValidatorTests                    DiamondPatternInheritedProperty
# 14     ContentCacheTests                                     CachesProvider
# 15     ContentCacheTests           CachesMultipleProvidersWithDifferentKeys
# 16     ContentCacheTests                    OverwritesProviderWhenKeysEqual
# 17     ContentCacheTests                                     ClearsAllCache
# 18     ContentCacheTests                            ClearsCacheByConnection
# 19     ContentCacheTests                             ClearsCacheByRulesetId
#
#               Author       Component                 Date
# 0            UnKnown        WSClient  2018-04-03 01:12:30
# 1            UnKnown        WSClient  2018-04-03 01:12:30
# 2            UnKnown        WSClient  2018-04-03 01:12:30
# 3         Sam.Wilson     DgnPlatform  2018-04-10 01:02:39
# 4        Earlin.Lutz        GeomLibs  2018-04-10 01:02:39
# 5        Earlin.Lutz        GeomLibs  2018-04-10 01:02:39
# 6        Earlin.Lutz        GeomLibs  2018-04-10 01:02:39
# 7      Joseph.Urbano       ecobjects  2018-04-13 01:37:26
# 8        Dan.Perlman       ecobjects  2018-04-13 01:37:26
# 9      Joseph.Urbano       ecobjects  2018-04-13 01:37:26
# 10     Joseph.Urbano       ecobjects  2018-04-13 01:37:26
# 11     Joseph.Urbano       ecobjects  2018-04-13 01:37:26
# 12     Joseph.Urbano       ecobjects  2018-04-13 01:37:26
# 13     Joseph.Urbano       ecobjects  2018-04-13 01:37:26
# 14  Grigas.Petraitis  ECPresentation  2018-04-13 01:37:26
# 15  Grigas.Petraitis  ECPresentation  2018-04-13 01:37:26
# 16  Grigas.Petraitis  ECPresentation  2018-04-13 01:37:26
# 17  Grigas.Petraitis  ECPresentation  2018-04-13 01:37:26
# 18  Grigas.Petraitis  ECPresentation  2018-04-13 01:37:26
# 19  Grigas.Petraitis  ECPresentation  2018-04-13 01:37:26

# %%
for i in df.groupby('Component'):
    fig = plt.figure(figsize=(size+3,size+3))
    sns.set_style("whitegrid")
    name = i[0]
    print name,
    X, Y = np.unique(i[1].Author, return_counts=True)
    colors = sns.color_palette("cubehelix", len(X) + 3)
    
    g = sns.barplot(x=X, y=Y, palette=colors, order = X)
    for i in range(np.shape(X)[0]):
        g.text(i, Y[i] + 0.5, Y[i], color='black', ha="center", weight="bold")
    g.set_title(name)
    sns.despine(left=True)
    plt.savefig("TEST/"+name+".svg")
# Out:
# BeHttp BeSQLite Bentley ComponentModeling DgnPlatform DgnV8 Dwg ECDb ECPresentation GeoCoord GeomLibs Units WSClient ecobjects iModelBridge
